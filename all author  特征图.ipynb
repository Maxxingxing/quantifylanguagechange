# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy

ti_lexical=pd.read_csv("DCLSA/la_dataset_split/tem/ti_all_lexical_matrix1.csv")
y=ti_lexical['lead.VBD']
x=ti_lexical.ix[:,-1]
plt.scatter(x,y,c='k',marker='.')

z = numpy.polyfit(x1, y1, 1)
p = numpy.poly1d(z)
plt.plot(x,p(x),"k--")


plt.xlabel('Time')
plt.ylabel('TF-IDF Value') #for each component
plt.title('<Tagged Lemma Feature: <lead.VBD>')

#pyl.plot(x,y,'k')
plt.show
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3a1d42ae238d> in <module>
#       7 plt.scatter(x,y,c='k',marker='.')
#       8
# ----> 9 z = numpy.polyfit(x1, y1, 1)
#      10 p = numpy.poly1d(z)
#      11 plt.plot(x,p(x),"k--")
#
# NameError: name 'numpy' is not defined

# %%
y=ti_lexical['not.RB']
x=ti_lexical.ix[:,-1]
z = numpy.polyfit(x, y, 1)
p = numpy.poly1d(z)
plt.plot(x,p(x),"k--")
plt.scatter(x,y,c='k',marker='.')


plt.xlabel('Time')
plt.ylabel('TF-IDF Value') #for each component
plt.title('Tagged Lemma Feature: <not.RB>')

#pyl.plot(x,y,'k')
plt.show
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import matplotlib.pyplot as plt

ti_lemma=pd.read_csv("DCLSA/la_dataset_split/tem/ti_all_lemma_matrix1.csv")
y=ti_lemma['king']
x=ti_lemma.ix[:,-1]
plt.scatter(x,y,c='k',marker='.')

z = numpy.polyfit(x1, y1, 1)
p = numpy.poly1d(z)
plt.plot(x,p(x),"k--")


plt.xlabel('Time')
plt.ylabel('TF-IDF Value') #for each component
plt.title('<Lemma Feature: <king>')

#pyl.plot(x,y,'k')
plt.show
# Out:
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
y=ti_lemma['avenue']
x=ti_lemma.ix[:,-1]
plt.scatter(x,y,c='k',marker='.')

z = numpy.polyfit(x1, y1, 1)
p = numpy.poly1d(z)
plt.plot(x,p(x),"k--")

plt.yticks(numpy.arange(0,0.045,0.005))
plt.xlabel('Time')
plt.ylabel('TF-IDF Value') #for each component
plt.title('Lemma Feature: <avenue>')

#pyl.plot(x,y,'k')
plt.show
# Out:
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import matplotlib.pyplot as plt

ti_pos=pd.read_csv("DCLSA/la_dataset_split/tem/ti_all_pos_matrix1.csv")
y=ti_pos['WP$']
x=ti_pos.ix[:,-1]
plt.scatter(x,y,c='k',marker='.')

z = numpy.polyfit(x1, y1, 1)
p = numpy.poly1d(z)
plt.plot(x,p(x),"k--")


plt.xlabel('Time')
plt.ylabel('TF-IDF Value') #for each component
plt.title('POS Feature: <WP$>')

#pyl.plot(x,y,'k')
plt.show
# Out:
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import numpy
ti_pos=pd.read_csv("DCLSA/la_dataset_split/tf_idf/ti_ew_pos_matrix.csv")
y1=ti_pos['RBS']
x1=ti_pos.ix[:,-1]
pyl.scatter(x1,y1,color='black')

z = numpy.polyfit(x1, y1, 1)
p = numpy.poly1d(z)
pyl.plot(x,p(x),"r--")

#pyl.scatter(x,y)
#pyl.plot(x,y,'k')
pyl.show
# Out:
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   after removing the cwd from sys.path.
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import numpy
ti_pos=pd.read_csv("DCLSA/la_dataset_split/tf_idf/ti_ew_lemma_matrix.csv")
y1=ti_pos['king']
x1=ti_pos.ix[:,-1]
pyl.scatter(x1,y1,color='black')

z = numpy.polyfit(x1, y1, 1)
p = numpy.poly1d(z)
pyl.plot(x,p(x),"r--")

#pyl.scatter(x,y)
#pyl.plot(x,y,'k')
pyl.show
# Out:
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   after removing the cwd from sys.path.
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import numpy
ti_pos=pd.read_csv("DCLSA/la_dataset_split/tf_idf/ti_rwc_lemma_matrix.csv")
y1=ti_pos['king']
x1=ti_pos.ix[:,-1]
pyl.scatter(x1,y1,color='black')

z = numpy.polyfit(x1, y1, 1)
p = numpy.poly1d(z)
pyl.plot(x,p(x),"r--")

#pyl.scatter(x,y)
#pyl.plot(x,y,'k')
pyl.show
# Out:
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   after removing the cwd from sys.path.
# <function matplotlib.pyplot.show(*args, **kw)>
